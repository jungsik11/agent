# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("beomi/gemma-ko-2b")
model = AutoModelForCausalLM.from_pretrained("beomi/gemma-ko-2b")
# Out:
# Fetching 2 files: 100%|██████████| 2/2 [01:19<00:00, 39.76s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:05<00:00,  2.99s/it]
